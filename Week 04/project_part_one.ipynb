# %%
# Dependencies
import pandas as pd

# %%
# load CSV
survey_data = (r"C:\Users\tommy\Documents\GWU-ARL-DATA-PT-09-2019-U-C\02-Homework\04-Pandas\Instructions\Part-1\Pandas_Mini_Project_Task_A\Resources\2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas
survey_data_df = pd.read_csv(survey_data)
low_memory = False

# %%
# Inspect all columns
survey_data_df.columns.tolist()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
clean_data_df = survey_data_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
clean_data_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million                NaN  United States of America
# 1  between 100,000 and 1 million                NaN  United States of America
# 2            more than 1 million                NaN  United States of America
# 3            more than 1 million                NaN  United States of America
# 4  between 100,000 and 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 0          0.0           30.0  32000.0                        NaN
# 1          NaN           30.0  15000.0    Front-End Web Developer
# 2          NaN           20.0  48000.0                        NaN
# 3          NaN           20.0  43000.0    Front-End Web Developer
# 4          NaN           25.0   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
clean_data_df = clean_data_df.replace({0.0:"No", 1.0:"Yes"})
clean_data_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# 1  between 100,000 and 1 million               NaN  United States of America
# 2            more than 1 million               NaN  United States of America
# 3            more than 1 million               NaN  United States of America
# 4  between 100,000 and 1 million               NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#   HasChildren HoursLearning   Income            JobRoleInterest  \
# 0          No            30  32000.0                        NaN
# 1         NaN            30  15000.0    Front-End Web Developer
# 2         NaN            20  48000.0                        NaN
# 3         NaN            20  43000.0    Front-End Web Developer
# 4         NaN            25   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Calculate total number of respondents in survey
total_surveyed = len(clean_data_df)
total_surveyed
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp = clean_data_df.loc[clean_data_df ["AttendedBootcamp"] == "Yes"]
attended_bootcamp
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# 206    36.0              Yes            Yes                   No
# 209    25.0              Yes            Yes                   No
# 236    52.0              Yes            Yes                  Yes
# 272    38.0              Yes            Yes                  Yes
# 273    35.0              Yes            Yes                  Yes
# 285    23.0              Yes            Yes                  Yes
# 315    31.0              Yes            Yes                   No
# 316    22.0              Yes            Yes                   No
# 328    30.0              Yes             No                  NaN
# 426    30.0              Yes            Yes                   No
# 435    26.0              Yes            Yes                   No
# 449    38.0              Yes            Yes                   No
# 465    40.0              Yes             No                  NaN
# 470    45.0              Yes             No                  NaN
# 478    37.0              Yes             No                  NaN
# 481    27.0              Yes            Yes                   No
# 488    25.0              Yes             No                  NaN
# 505    28.0              Yes            Yes                  Yes
# 506    38.0              Yes            Yes                   No
# 510    33.0              Yes             No                  NaN
# 522    33.0              Yes            Yes                   No
# 525    31.0              Yes             No                  NaN
# 526    30.0              Yes             No                  NaN
# 533    20.0              Yes             No                  NaN
# 543    27.0              Yes            Yes                  Yes
# ...     ...              ...            ...                  ...
# 14653  29.0              Yes            Yes                  Yes
# 14681  24.0              Yes            Yes                   No
# 14695  22.0              Yes             No                  NaN
# 14701  23.0              Yes             No                  NaN
# 14751  29.0              Yes            Yes                  Yes
# 14766  25.0              Yes            Yes                   No
# 14797  37.0              Yes             No                  NaN
# 14846  15.0              Yes             No                  NaN
# 14987   NaN              Yes             No                  NaN
# 14992  24.0              Yes             No                  NaN
# 15062  29.0              Yes             No                  NaN
# 15106  24.0              Yes            Yes                  Yes
# 15128  24.0              Yes            Yes                   No
# 15165  26.0              Yes             No                  NaN
# 15188  29.0              Yes             No                  NaN
# 15239  28.0              Yes            Yes                  Yes
# 15348  24.0              Yes             No                  NaN
# 15395  31.0              Yes            NaN                  NaN
# 15400  32.0              Yes             No                  NaN
# 15406  23.0              Yes            Yes                  Yes
# 15412  24.0              Yes            Yes                   No
# 15420  25.0              Yes            Yes                  Yes
# 15421  22.0              Yes            Yes                   No
# 15436  45.0              Yes             No                  NaN
# 15465  25.0              Yes             No                  NaN
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                   No                 NaN                No            NaN
# 97                   No             45000.0                No            NaN
# 130                 Yes             75000.0               Yes              3
# 159                  No                 NaN                No            NaN
# 188                 Yes                 NaN                No            NaN
# 206                  No                 NaN                No              2
# 209                 Yes                 NaN               Yes            NaN
# 236                  No             45000.0                No            NaN
# 272                 Yes             50000.0               Yes            NaN
# 273                 Yes             60000.0               Yes            NaN
# 285                  No             40000.0               Yes            NaN
# 315                  No                 NaN                No            NaN
# 316                  No                 NaN               Yes            NaN
# 328                  No                 NaN               Yes            NaN
# 426                 Yes                 NaN               Yes            NaN
# 435                 Yes                 NaN               Yes            NaN
# 449                  No                 NaN               Yes            NaN
# 465                 Yes                 NaN               Yes            NaN
# 470                  No                 NaN               Yes            NaN
# 478                 Yes                 NaN               Yes            NaN
# 481                  No                 NaN               Yes            NaN
# 488                 Yes                 NaN               Yes            NaN
# 505                 Yes             50000.0               Yes            Yes
# 506                  No                 NaN               Yes              2
# 510                  No                 NaN               Yes            NaN
# 522                 Yes                 NaN                No            NaN
# 525                  No                 NaN               Yes            NaN
# 526                  No                 NaN               Yes            NaN
# 533                  No                 NaN               Yes            NaN
# 543                  No             58000.0               Yes            NaN
# ...                 ...                 ...               ...            ...
# 14653                No             50000.0               Yes            NaN
# 14681                No                 NaN               Yes            NaN
# 14695                No                 NaN               Yes            NaN
# 14701               Yes                 NaN               Yes            NaN
# 14751                No             90000.0                No            NaN
# 14766                No                 NaN                No            NaN
# 14797                No                 NaN               Yes              3
# 14846                No                 NaN               Yes            NaN
# 14987                No                 NaN               Yes            NaN
# 14992                No                 NaN               Yes            NaN
# 15062               Yes                 NaN               Yes            NaN
# 15106                No             50000.0               Yes            NaN
# 15128               Yes                 NaN               Yes            NaN
# 15165                No                 NaN               Yes            NaN
# 15188                No                 NaN               Yes            NaN
# 15239                No             65000.0               Yes            NaN
# 15348                No                 NaN               Yes            NaN
# 15395               NaN                 NaN               Yes            NaN
# 15400                No                 NaN                No            NaN
# 15406                No             79000.0               Yes            NaN
# 15412               Yes                 NaN               Yes            NaN
# 15420                No             10000.0                No            NaN
# 15421                No                 NaN               Yes            NaN
# 15436                No                 NaN               Yes            Yes
# 15465                No                 NaN               Yes            NaN
# 15539               Yes                 NaN               Yes            NaN
# 15540               Yes                 NaN                No            NaN
# 15541                No             21600.0               Yes            NaN
# 15593                No                 NaN                No            NaN
# 15600                No             36000.0               Yes            NaN
#
#                       CityPopulation CodeEventBootcamp  \
# 93     between 100,000 and 1 million               NaN
# 97               more than 1 million               NaN
# 130                less than 100,000               NaN
# 159    between 100,000 and 1 million               NaN
# 188    between 100,000 and 1 million               NaN
# 206              more than 1 million               NaN
# 209              more than 1 million               NaN
# 236    between 100,000 and 1 million               NaN
# 272    between 100,000 and 1 million               NaN
# 273    between 100,000 and 1 million               NaN
# 285                              NaN               NaN
# 315    between 100,000 and 1 million               NaN
# 316    between 100,000 and 1 million               NaN
# 328    between 100,000 and 1 million               NaN
# 426                less than 100,000               NaN
# 435              more than 1 million               NaN
# 449              more than 1 million               NaN
# 465    between 100,000 and 1 million               NaN
# 470    between 100,000 and 1 million               NaN
# 478    between 100,000 and 1 million               NaN
# 481                less than 100,000               NaN
# 488    between 100,000 and 1 million               NaN
# 505              more than 1 million               NaN
# 506              more than 1 million               NaN
# 510              more than 1 million               NaN
# 522                less than 100,000               NaN
# 525    between 100,000 and 1 million               NaN
# 526    between 100,000 and 1 million               NaN
# 533    between 100,000 and 1 million               NaN
# 543                less than 100,000               NaN
# ...                              ...               ...
# 14653  between 100,000 and 1 million               NaN
# 14681            more than 1 million               NaN
# 14695            more than 1 million               NaN
# 14701  between 100,000 and 1 million               NaN
# 14751  between 100,000 and 1 million               NaN
# 14766              less than 100,000               NaN
# 14797            more than 1 million               NaN
# 14846  between 100,000 and 1 million               NaN
# 14987              less than 100,000               NaN
# 14992            more than 1 million               NaN
# 15062            more than 1 million               NaN
# 15106                            NaN               NaN
# 15128            more than 1 million               NaN
# 15165              less than 100,000               NaN
# 15188            more than 1 million               NaN
# 15239  between 100,000 and 1 million               NaN
# 15348            more than 1 million               NaN
# 15395  between 100,000 and 1 million               NaN
# 15400            more than 1 million               NaN
# 15406  between 100,000 and 1 million               NaN
# 15412              less than 100,000               NaN
# 15420            more than 1 million               NaN
# 15421            more than 1 million               NaN
# 15436  between 100,000 and 1 million               NaN
# 15465  between 100,000 and 1 million               NaN
# 15539            more than 1 million               NaN
# 15540            more than 1 million               NaN
# 15541            more than 1 million               NaN
# 15593            more than 1 million               NaN
# 15600  between 100,000 and 1 million               NaN
#
#                     CountryLive                        EmploymentField  \
# 93     United States of America  arts, entertainment, sports, or media
# 97     United States of America                   software development
# 130    United States of America                   software development
# 159    United States of America                                    NaN
# 188                      Canada                                    NaN
# 206                       Japan                                    NaN
# 209                      Mexico                                    NaN
# 236    United States of America                   software development
# 272    United States of America                   software development
# 273    United States of America                   software development
# 285    United States of America                   software development
# 315    United States of America                   software development
# 316    United States of America                                    NaN
# 328    United States of America                                  sales
# 426    United States of America                              education
# 435    United States of America                                    NaN
# 449    United States of America                                    NaN
# 465    United States of America                                    NaN
# 470    United States of America                                    NaN
# 478    United States of America                                    NaN
# 481    United States of America                                    NaN
# 488    United States of America                                    NaN
# 505    United States of America            software development and IT
# 506    United States of America                                    NaN
# 510                   Australia                                    NaN
# 522    United States of America                                    NaN
# 525    United States of America                                    NaN
# 526    United States of America                                    NaN
# 533                       India            software development and IT
# 543    United States of America            software development and IT
# ...                         ...                                    ...
# 14653  United States of America            software development and IT
# 14681                   Ukraine            software development and IT
# 14695                     India            software development and IT
# 14701                   Romania                                finance
# 14751  United States of America            software development and IT
# 14766  United States of America            software development and IT
# 14797                  Malaysia            software development and IT
# 14846  United States of America                              education
# 14987  United States of America      office and administrative support
# 14992                   Nigeria            software development and IT
# 15062  United States of America                                    NaN
# 15106  United States of America            software development and IT
# 15128  United States of America            software development and IT
# 15165  United States of America  arts, entertainment, sports, or media
# 15188               Philippines            software development and IT
# 15239  United States of America            software development and IT
# 15348                   Vietnam            software development and IT
# 15395               Puerto Rico                                  legal
# 15400              Saudi Arabia            software development and IT
# 15406  United States of America            software development and IT
# 15412  United States of America            software development and IT
# 15420                     India            software development and IT
# 15421                   Nigeria            software development and IT
# 15436                   Ukraine            construction and extraction
# 15465                   Ukraine   architecture or physical engineering
# 15539                    Mexico                                    NaN
# 15540                     Kenya  arts, entertainment, sports, or media
# 15541                    Mexico            software development and IT
# 15593                     India            software development and IT
# 15600  United States of America            software development and IT
#
#                            EmploymentStatus       Gender HasChildren  \
# 93             Self-employed business owner         male         NaN
# 97                       Employed for wages         male          No
# 130                      Employed for wages         male         Yes
# 159    Not working and not looking for work       female         NaN
# 188        Not working but looking for work       female         NaN
# 206      A stay-at-home parent or homemaker       female         Yes
# 209        Not working but looking for work         male         NaN
# 236                Self-employed freelancer         male         NaN
# 272                      Employed for wages         male         NaN
# 273                      Employed for wages         male         NaN
# 285                      Employed for wages         male         NaN
# 315                Self-employed freelancer  genderqueer         NaN
# 316        Not working but looking for work         male         NaN
# 328                      Employed for wages       female         NaN
# 426                      Employed for wages         male         NaN
# 435        Not working but looking for work         male         NaN
# 449        Not working but looking for work       female         NaN
# 465      A stay-at-home parent or homemaker       female         NaN
# 470    Not working and not looking for work       female         NaN
# 478                                     NaN       female         NaN
# 481        Not working but looking for work       female         NaN
# 488                          Unable to work         male         NaN
# 505                      Employed for wages         male         Yes
# 506        Not working but looking for work       female         Yes
# 510    Not working and not looking for work         male         NaN
# 522                      Employed for wages         male         NaN
# 525    Not working and not looking for work       female         NaN
# 526        Not working but looking for work       female         NaN
# 533                      Employed for wages         male         NaN
# 543                      Employed for wages       female         NaN
# ...                                     ...          ...         ...
# 14653                    Employed for wages       female         NaN
# 14681              Self-employed freelancer         male          No
# 14695                    Employed for wages         male          No
# 14701                    Employed for wages         male         NaN
# 14751                    Employed for wages         male          No
# 14766          Self-employed business owner         male         NaN
# 14797              Self-employed freelancer         male         Yes
# 14846                    Employed for wages       female         NaN
# 14987                    Employed for wages       female         NaN
# 14992                    Employed for wages         male          No
# 15062                    Employed for wages  genderqueer         NaN
# 15106                    Employed for wages       female         NaN
# 15128                    Employed for wages       female          No
# 15165              Self-employed freelancer         male         NaN
# 15188                    Employed for wages       female          No
# 15239                    Employed for wages         male         NaN
# 15348              Self-employed freelancer         male         NaN
# 15395                    Employed for wages       female         NaN
# 15400              Self-employed freelancer       female         NaN
# 15406                    Employed for wages         male         NaN
# 15412              Self-employed freelancer         male         NaN
# 15420                    Employed for wages         male          No
# 15421              Self-employed freelancer         male         NaN
# 15436              Self-employed freelancer         male         Yes
# 15465                    Employed for wages         male         NaN
# 15539              Self-employed freelancer       female         NaN
# 15540                    Employed for wages       female         NaN
# 15541                    Employed for wages         male         NaN
# 15593                    Employed for wages       female          No
# 15600                    Employed for wages       female         NaN
#
#       HoursLearning    Income               JobRoleInterest  \
# 93               20   67000.0                           NaN
# 97               10   40000.0                           NaN
# 130              30   75000.0                           NaN
# 159              30       NaN      Full-Stack Web Developer
# 188              60       NaN                           NaN
# 206              20       NaN              Mobile Developer
# 209              40       NaN      Full-Stack Web Developer
# 236              30   45000.0                           NaN
# 272               5       NaN                           NaN
# 273              10   54000.0                           NaN
# 285              40       NaN                           NaN
# 315              20   35000.0      User Experience Designer
# 316              30       NaN       Front-End Web Developer
# 328              20   35000.0       Front-End Web Developer
# 426              40       NaN      Full-Stack Web Developer
# 435              50       NaN       Front-End Web Developer
# 449              20       NaN                           NaN
# 465               8       NaN    Quality Assurance Engineer
# 470              50       NaN              Mobile Developer
# 478              50       NaN      Full-Stack Web Developer
# 481               2       NaN       Front-End Web Developer
# 488               9       NaN       Front-End Web Developer
# 505              15   38000.0                           NaN
# 506              25       NaN        Back-End Web Developer
# 510              60       NaN      Full-Stack Web Developer
# 522              10       NaN      Full-Stack Web Developer
# 525              50       NaN      Full-Stack Web Developer
# 526              50       NaN        Back-End Web Developer
# 533               6    6000.0                           NaN
# 543               5   43000.0                           NaN
# ...             ...       ...                           ...
# 14653             5   15600.0                           NaN
# 14681             4   60000.0                           NaN
# 14695            90   24000.0                           NaN
# 14701             8   60000.0              Mobile Developer
# 14751            20   48000.0                           NaN
# 14766            50   48000.0      Full-Stack Web Developer
# 14797            20   28800.0                           NaN
# 14846            10    8400.0        Back-End Web Developer
# 14987            40   60000.0                           NaN
# 14992            10   51432.0                           NaN
# 15062            20   36000.0             DevOps / SysAdmin
# 15106            10   48000.0                           NaN
# 15128            30   18000.0      Full-Stack Web Developer
# 15165            40   48000.0      Full-Stack Web Developer
# 15188            25   28560.0                           NaN
# 15239            45   48000.0                           NaN
# 15348            30   12000.0                           NaN
# 15395             6   60000.0                           NaN
# 15400            12   24000.0                           NaN
# 15406            No   12000.0                           NaN
# 15412            10   36000.0      Full-Stack Web Developer
# 15420           NaN   12000.0                           NaN
# 15421            30    7200.0      Full-Stack Web Developer
# 15436             5   36000.0      Full-Stack Web Developer
# 15465            15   14400.0        Back-End Web Developer
# 15539            15   36000.0      Full-Stack Web Developer
# 15540            10   16800.0                           NaN
# 15541            24   42000.0                           NaN
# 15593             5  200000.0                           NaN
# 15600             8  200000.0                           NaN
#
#                                    SchoolDegree  \
# 93                            bachelor's degree
# 97           master's degree (non-professional)
# 130              some college credit, no degree
# 159              some college credit, no degree
# 188              some college credit, no degree
# 206                           bachelor's degree
# 209     professional degree (MBA, MD, JD, etc.)
# 236              some college credit, no degree
# 272                           bachelor's degree
# 273                           bachelor's degree
# 285                           bachelor's degree
# 315                           bachelor's degree
# 316                          associate's degree
# 328                           bachelor's degree
# 426                           bachelor's degree
# 435                          associate's degree
# 449                           bachelor's degree
# 465          master's degree (non-professional)
# 470                           bachelor's degree
# 478                           bachelor's degree
# 481    trade, technical, or vocational training
# 488                           bachelor's degree
# 505              some college credit, no degree
# 506                           bachelor's degree
# 510    trade, technical, or vocational training
# 522                           bachelor's degree
# 525                           bachelor's degree
# 526                           bachelor's degree
# 533                           bachelor's degree
# 543                           bachelor's degree
# ...                                         ...
# 14653                         bachelor's degree
# 14681                         bachelor's degree
# 14695                         bachelor's degree
# 14701                          some high school
# 14751                         bachelor's degree
# 14766  trade, technical, or vocational training
# 14797                         bachelor's degree
# 14846                          some high school
# 14987                        associate's degree
# 14992                        associate's degree
# 15062  trade, technical, or vocational training
# 15106            some college credit, no degree
# 15128                        associate's degree
# 15165        master's degree (non-professional)
# 15188                         bachelor's degree
# 15239                         bachelor's degree
# 15348   high school diploma or equivalent (GED)
# 15395            some college credit, no degree
# 15400   professional degree (MBA, MD, JD, etc.)
# 15406                         bachelor's degree
# 15412                         bachelor's degree
# 15420                         bachelor's degree
# 15421   high school diploma or equivalent (GED)
# 15436   high school diploma or equivalent (GED)
# 15465        master's degree (non-professional)
# 15539            some college credit, no degree
# 15540                         bachelor's degree
# 15541        master's degree (non-professional)
# 15593                         bachelor's degree
# 15600                         bachelor's degree
#
#                                              SchoolMajor
# 93                                               Biology
# 97                                                 Music
# 130                                                  NaN
# 159                                                  NaN
# 188                                                  NaN
# 206                                       Communications
# 209                                     Computer Science
# 236                                                  NaN
# 272                               Structural Engineering
# 273                                Public Administration
# 285                                           Journalism
# 315                                       Communications
# 316                                      General Studies
# 328                            Advertising and Marketing
# 426                                         Liberal Arts
# 435                                           Psychology
# 449                                         Architecture
# 465                                              English
# 470                                         Liberal Arts
# 478                                            Sociology
# 481                                                  NaN
# 488                                           Psychology
# 505                                                  NaN
# 506                                         Anthropology
# 510                                                  NaN
# 522                                           Psychology
# 525                                           Psychology
# 526                                            Nutrition
# 533                                       Communications
# 543                              Business Administration
# ...                                                  ...
# 14653                                  Political Science
# 14681                                   Computer Science
# 14695                                   Computer Science
# 14701                                                NaN
# 14751                             Industrial Engineering
# 14766                                                NaN
# 14797                             Electrical Engineering
# 14846                                                NaN
# 14987                                Computer Networking
# 14992                               Software Engineering
# 15062                                                NaN
# 15106                                                NaN
# 15128                                   Computer Science
# 15165                                  Music Performance
# 15188                                        Engineering
# 15239                                       Neuroscience
# 15348                                                NaN
# 15395                                                NaN
# 15400  Computer Systems Networking and Telecommunicat...
# 15406                                            History
# 15412                                            English
# 15420                             Information Technology
# 15421                                                NaN
# 15436                                                NaN
# 15465             Electrical and Electronics Engineering
# 15539                                                NaN
# 15540  Computer Systems Networking and Telecommunicat...
# 15541                      Computer Software Engineering
# 15593                                         Accounting
# 15600                                          Marketing
#
# [953 rows x 20 columns]

# %%
# Calculate average age of attendees
average_age = attended_bootcamp["Age"].mean()

# Calculate how many people attended a bootcamp
amount_attended = attended_bootcamp["AttendedBootcamp"].count()

# Calculate how many attendees hold degrees
holds_degree = attended_bootcamp["SchoolDegree"].count()

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
total_gender = attended_bootcamp["Gender"].count()
male = attended_bootcamp["Gender"].value_counts()['male']
female = attended_bootcamp["Gender"].value_counts()['female']
non_gender = total_gender - male - female

# Calculate percentage of respondents who attended a bootcamp
percent_attended = amount_attended / total_surveyed * 100

# Calculate percentage of respondents belonging to each gender
percent_male = (male / total_gender) * 100
percent_female = (female / total_gender) * 100
percent_non_gender = (non_gender / total_gender) * 100

# Calculate percentage of attendees with a school degree
percent_degree = holds_degree / amount_attended * 100

# Calculate average post-bootcamp salary
avg_salary = attended_bootcamp["BootcampPostSalary"].mean()
avg_salary
# Out:
# 63740.50606060606

# %%
# Create a new table consolodating above calculations
bootcamp_breakdown = pd.DataFrame({"Total Surveyed":[total_surveyed],
                                   "Total bootcamp attendees":[amount_attended],
                                   "% attended bootcamp":[percent_attended],
                                   "Avg. Age":[average_age],
                                   "% male":[percent_male],
                                   "% female":[percent_female],
                                   "% nonbinary":[percent_non_gender],
                                   "Has a degree":[percent_degree],
                                   "Avg post bootcamp salary":[avg_salary]
                                  })
bootcamp_breakdown = bootcamp_breakdown[["Total Surveyed", "Total bootcamp attendees", "% attended bootcamp", "Avg. Age", "% male", "% female", "% nonbinary", "Has a degree", "Avg post bootcamp salary"]]
bootcamp_breakdown = bootcamp_breakdown.round(2)

bootcamp_breakdown
# Out:
#    Total Surveyed  Total bootcamp attendees  % attended bootcamp  Avg. Age  \
# 0           15620                       953                  6.1     31.07
#
#    % male  % female  % nonbinary  Has a degree  Avg post bootcamp salary
# 0   59.54     39.14         1.32          87.3                  63740.51

# %%
# Improve formatting before outputting spreadsheet
bootcamp_breakdown["% male"] = bootcamp_breakdown["% male"].map("{0:,.2f}%".format)
bootcamp_breakdown["% female"] = bootcamp_breakdown["% female"].map("{0:,.2f}%".format)
bootcamp_breakdown["% nonbinary"] = bootcamp_breakdown["% nonbinary"].map("{0:,.2f}%".format)
bootcamp_breakdown["% attended bootcamp"] = bootcamp_breakdown["% attended bootcamp"].map("{0:,.2f}%".format)
bootcamp_breakdown["Has a degree"] = bootcamp_breakdown["Has a degree"].map("{0:,.2f}%".format)
bootcamp_breakdown["Avg post bootcamp salary"] = bootcamp_breakdown["Avg post bootcamp salary"].map("{0:,.0f}%".format)
bootcamp_breakdown
# Out:
#    Total Surveyed  Total bootcamp attendees % attended bootcamp  Avg. Age  \
# 0           15620                       953               6.10%     31.07
#
#    % male % female % nonbinary Has a degree Avg post bootcamp salary
# 0  59.54%   39.14%       1.32%       87.30%                  63,741%

# %%
# Export to Excel
bootcamp_breakdown.to_excel(r"C:\Users\tommy\OneDrive\Documents\Personal homework use\Week  04/Bootcamppart1.xlsx", index=False)
